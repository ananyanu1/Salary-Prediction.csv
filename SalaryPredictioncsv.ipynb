# %%
from sklearn.linear_model import LinearRegression
import pandas as pd
LR=LinearRegression()

# %%
data_student=pd.read_csv("/content/drive/MyDrive/SalaryPrediction.csv")

# %%
data_student.shape
# Out:
# (40, 2)

# %%
data =data_student.sample(frac=1)
data.head(10)
# Out:
#     Experience Years  Salary
# 26               6.0   93940
# 23               5.3   83088
# 19               4.5   61111
# 28               6.5   90000
# 37               9.6  112635
# 20               4.7   64500
# 27               6.2   91000
# 6                2.5   48266
# 8                3.0   60150
# 35               9.0  105582

# %%
def filtering(data):
    text=data.lower()
    text=re.sub('\[.*?\]','',text)
    text=re.sub("\\W"," ",text)
    text=re.sub('https?://\s+|www\.S+','',text)
    text=re.sub('<.*?>+','',text)
    text=re.sub('[%s]'%re.escape(string.punctuation),'',text)
    text=re.sub('\n','',text)
    text=re.sub('\w*\d\w*','',text)
    return text

# %%
x=data_student["Experience Years"]
y=data_student["Salary"]

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# Assuming 'data_student' is your DataFrame and 'GPA' and 'GradeClass' are valid columns
x = data_student["Experience Years"].values.reshape(-1, 1)  # Reshape for sklearn
y = data_student["Salary"]

# Create a LinearRegression model object
model = LinearRegression()

# Fit the model to your data
model.fit(x, y)

# Split the data into training and testing sets (optional, but recommended for evaluating model performance)
# x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# Now you can access the coefficient
print("Coefficient:", model.coef_[0])
# Out:
# Coefficient: 9523.650507417704
